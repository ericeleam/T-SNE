# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
#.txt 
file_path = "jawn.txt"
df = pd.read_csv(file_path, sep="\t") #/t for .txt , for .csv
df_filtered = df.loc[:, ~df.columns.str.contains('.pval', case=False, regex=True)]
X = df_filtered.iloc[:500, 1:]

# %%
#Print first 5 rows of the dataframe
print(X.head())
# Out:
#    X204674440015_R01C01.2.Methylated.Signal  \
# 0                                       264
# 1                                        90
# 2                                      3962
# 3                                       256
# 4                                      5440
#
#    X204674440015_R01C01.3.Detection.Pval  \
# 0                          6.710000e-284
# 1                           3.210000e-05
# 2                           1.470000e-62
# 3                           1.090000e-47
# 4                           5.800000e-80
#
#    X204674440015_R03C01.2.Methylated.Signal  \
# 0                                       350
# 1                                       121
# 2                                      4310
# 3                                       797
# 4                                      6021
#
#    X204674440015_R03C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                           1.670000e-20
# 2                          6.200000e-100
# 3                           1.000000e-53
# 4                           2.890000e-86
#
#    X204674440015_R04C01.2.Methylated.Signal  \
# 0                                       241
# 1                                       306
# 2                                      1121
# 3                                       302
# 4                                      2360
#
#    X204674440015_R04C01.3.Detection.Pval  \
# 0                          4.720000e-270
# 1                           2.278202e-03
# 2                           2.000000e-22
# 3                           3.510000e-23
# 4                           2.330000e-20
#
#    X204674440015_R06C01.2.Methylated.Signal  \
# 0                                       242
# 1                                       309
# 2                                      2725
# 3                                       791
# 4                                      4930
#
#    X204674440015_R06C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                           5.070000e-19
# 2                           8.270000e-76
# 3                           3.110000e-57
# 4                           1.920000e-96
#
#    X204674440043_R03C01.2.Methylated.Signal  \
# 0                                       317
# 1                                       115
# 2                                      2915
# 3                                       840
# 4                                      4756
#
#    X204674440043_R03C01.3.Detection.Pval  ...  \
# 0                           0.000000e+00  ...
# 1                           1.030000e-31  ...
# 2                           1.820000e-76  ...
# 3                           3.750000e-69  ...
# 4                           2.590000e-70  ...
#
#    X204676960031_R04C01.2.Methylated.Signal  \
# 0                                       311
# 1                                       247
# 2                                      4089
# 3                                       881
# 4                                      3968
#
#    X204676960031_R04C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                          3.180000e-149
# 2                          6.330000e-282
# 3                           1.460000e-86
# 4                          1.070000e-117
#
#    X204676960031_R05C01.2.Methylated.Signal  \
# 0                                       358
# 1                                       168
# 2                                      4730
# 3                                       548
# 4                                      5247
#
#    X204676960031_R05C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                           2.960000e-95
# 2                          1.990000e-248
# 3                          2.580000e-156
# 4                          4.390000e-181
#
#    X204676960031_R06C01.2.Methylated.Signal  \
# 0                                       322
# 1                                       132
# 2                                      2323
# 3                                       735
# 4                                      4720
#
#    X204676960031_R06C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                           6.250000e-60
# 2                          2.170000e-103
# 3                           1.530000e-51
# 4                          1.460000e-122
#
#    X204676960031_R07C01.2.Methylated.Signal  \
# 0                                       232
# 1                                       196
# 2                                      3320
# 3                                       772
# 4                                      5313
#
#    X204676960031_R07C01.3.Detection.Pval  \
# 0                           0.000000e+00
# 1                           2.420000e-82
# 2                          1.310000e-239
# 3                           1.560000e-67
# 4                          1.880000e-188
#
#    X204676960031_R08C01.2.Methylated.Signal  \
# 0                                       193
# 1                                       148
# 2                                       475
# 3                                       130
# 4                                      2696
#
#    X204676960031_R08C01.3.Detection.Pval
# 0                           0.000000e+00
# 1                           7.964850e-04
# 2                           1.720000e-29
# 3                           1.820000e-51
# 4                           4.330000e-91
#
# [5 rows x 80 columns]

# %%
X_scaled = StandardScaler().fit_transform(X)

tsne = TSNE(n_components=2, perplexity=10, random_state=42)
X_embedded = tsne.fit_transform(X_scaled)

# Plot results
plt.figure(figsize=(10, 6))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], alpha=0.7)
plt.title("GSE211483")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
print(f"Number of points plotted: {len(X_embedded)}")
plt.show()
# Out:
# Number of points plotted: 500
